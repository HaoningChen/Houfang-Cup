# %%
import pickle

data_to_load = {
    "X_train": None,
    "X_valid": None,
    "X_test": None,
    "y_train": None,
    "y_valid": None,
    "y_test": None,
    "y_mean": None, 
    "y_std": None,
    "df_test": None
}
for k in data_to_load.keys():
    with open(k + ".pkl", 'rb') as file:
        data_to_load[k] = pickle.load(file)
X_train, X_valid, X_test = data_to_load["X_train"], data_to_load["X_valid"], data_to_load["X_test"]
y_train, y_valid, y_test = data_to_load["y_train"], data_to_load["y_valid"], data_to_load["y_test"]
y_mean, y_std = data_to_load["y_mean"], data_to_load["y_std"]
df_test = data_to_load["df_test"]

# %%
import scutquant.scutquant as q
import pandas as pd

model = q.hybrid()
model.fit(X_train, y_train, X_valid, y_valid)

pred = model.predict(X_test)

pred = pd.DataFrame(pred, columns=["predict"], index=X_test.index)
pred["predict"] += y_mean
pred["predict"] *= y_std
pred.describe()
# Out:
# [0]	validation_0-rmse:1.06489
# [1]	validation_0-rmse:1.05556
# [2]	validation_0-rmse:1.04693
# [3]	validation_0-rmse:1.03897
# [4]	validation_0-rmse:1.03158
# [5]	validation_0-rmse:1.02476
# [6]	validation_0-rmse:1.01844
# [7]	validation_0-rmse:1.01265
# [8]	validation_0-rmse:1.00727
# [9]	validation_0-rmse:1.00230
# [10]	validation_0-rmse:0.99774
# [11]	validation_0-rmse:0.99355
# [12]	validation_0-rmse:0.98967
# [13]	validation_0-rmse:0.98611
# [14]	validation_0-rmse:0.98281
# [15]	validation_0-rmse:0.97980
# [16]	validation_0-rmse:0.97700
# [17]	validation_0-rmse:0.97443
# [18]	validation_0-rmse:0.97206
# [19]	validation_0-rmse:0.96989
# [20]	validation_0-rmse:0.96788
# [21]	validation_0-rmse:0.96604
# [22]	validation_0-rmse:0.96434
# [23]	validation_0-rmse:0.96278
# [24]	validation_0-rmse:0.96135
# [25]	validation_0-rmse:0.96003
# [26]	validation_0-rmse:0.95882
# [27]	validation_0-rmse:0.95772
# [28]	validation_0-rmse:0.95670
# [29]	validation_0-rmse:0.95576
# [30]	validation_0-rmse:0.95490
# [31]	validation_0-rmse:0.95411
# [32]	validation_0-rmse:0.95338
# [33]	validation_0-rmse:0.95269
# [34]	validation_0-rmse:0.95207
# [35]	validation_0-rmse:0.95151
# [36]	validation_0-rmse:0.95099
# [37]	validation_0-rmse:0.95050
# [38]	validation_0-rmse:0.95006
# [39]	validation_0-rmse:0.94964
# [40]	validation_0-rmse:0.94926
# [41]	validation_0-rmse:0.94892
# [42]	validation_0-rmse:0.94861
# [43]	validation_0-rmse:0.94831
# [44]	validation_0-rmse:0.94804
# [45]	validation_0-rmse:0.94778
# [46]	validation_0-rmse:0.94757
# [47]	validation_0-rmse:0.94736
# [48]	validation_0-rmse:0.94716
# [49]	validation_0-rmse:0.94699
# [50]	validation_0-rmse:0.94683
# [51]	validation_0-rmse:0.94668
# [52]	validation_0-rmse:0.94654
# [53]	validation_0-rmse:0.94640
# [54]	validation_0-rmse:0.94629
# [55]	validation_0-rmse:0.94617
# [56]	validation_0-rmse:0.94607
# [57]	validation_0-rmse:0.94599
# [58]	validation_0-rmse:0.94590
# [59]	validation_0-rmse:0.94582
# [60]	validation_0-rmse:0.94576
# [61]	validation_0-rmse:0.94569
# [62]	validation_0-rmse:0.94563
# [63]	validation_0-rmse:0.94557
# [64]	validation_0-rmse:0.94551
# [65]	validation_0-rmse:0.94546
# [66]	validation_0-rmse:0.94542
# [67]	validation_0-rmse:0.94538
# [68]	validation_0-rmse:0.94533
# [69]	validation_0-rmse:0.94530
# [70]	validation_0-rmse:0.94526
# [71]	validation_0-rmse:0.94522
# [72]	validation_0-rmse:0.94519
# [73]	validation_0-rmse:0.94516
# [74]	validation_0-rmse:0.94514
# [75]	validation_0-rmse:0.94512
# [76]	validation_0-rmse:0.94508
# [77]	validation_0-rmse:0.94506
# [78]	validation_0-rmse:0.94503
# [79]	validation_0-rmse:0.94501
# [80]	validation_0-rmse:0.94499
# [81]	validation_0-rmse:0.94496
# [82]	validation_0-rmse:0.94495
# [83]	validation_0-rmse:0.94494
# [84]	validation_0-rmse:0.94492
# [85]	validation_0-rmse:0.94490
# [86]	validation_0-rmse:0.94488
# [87]	validation_0-rmse:0.94487
# [88]	validation_0-rmse:0.94486
# [89]	validation_0-rmse:0.94485
# [90]	validation_0-rmse:0.94484
# [91]	validation_0-rmse:0.94483
# [92]	validation_0-rmse:0.94481
# [93]	validation_0-rmse:0.94481
# [94]	validation_0-rmse:0.94480
# [95]	validation_0-rmse:0.94477
# [96]	validation_0-rmse:0.94477
# [97]	validation_0-rmse:0.94476
# [98]	validation_0-rmse:0.94473
# [99]	validation_0-rmse:0.94472
# [100]	validation_0-rmse:0.94471
# [101]	validation_0-rmse:0.94471
# [102]	validation_0-rmse:0.94471
# [103]	validation_0-rmse:0.94469
# [104]	validation_0-rmse:0.94469
# [105]	validation_0-rmse:0.94469
# [106]	validation_0-rmse:0.94469
# [107]	validation_0-rmse:0.94469
# [108]	validation_0-rmse:0.94468
# [109]	validation_0-rmse:0.94466
# [110]	validation_0-rmse:0.94466
# [111]	validation_0-rmse:0.94466
# [112]	validation_0-rmse:0.94465
# [113]	validation_0-rmse:0.94464
# [114]	validation_0-rmse:0.94463
# [115]	validation_0-rmse:0.94463
# [116]	validation_0-rmse:0.94462
# [117]	validation_0-rmse:0.94462
# [118]	validation_0-rmse:0.94460
# [119]	validation_0-rmse:0.94459
# [120]	validation_0-rmse:0.94457
# [121]	validation_0-rmse:0.94459
# [122]	validation_0-rmse:0.94457
# [123]	validation_0-rmse:0.94457
# [124]	validation_0-rmse:0.94457
# [125]	validation_0-rmse:0.94457
# [126]	validation_0-rmse:0.94455
# [127]	validation_0-rmse:0.94455
# [128]	validation_0-rmse:0.94454
# [129]	validation_0-rmse:0.94454
# [130]	validation_0-rmse:0.94454
# [131]	validation_0-rmse:0.94455
# [132]	validation_0-rmse:0.94453
# [133]	validation_0-rmse:0.94453
# [134]	validation_0-rmse:0.94452
# [135]	validation_0-rmse:0.94451
# [136]	validation_0-rmse:0.94451
# [137]	validation_0-rmse:0.94451
# [138]	validation_0-rmse:0.94451
# [139]	validation_0-rmse:0.94452
# [140]	validation_0-rmse:0.94451
# [141]	validation_0-rmse:0.94451
# [142]	validation_0-rmse:0.94449
# [143]	validation_0-rmse:0.94450
# [144]	validation_0-rmse:0.94450
# [145]	validation_0-rmse:0.94449
# [146]	validation_0-rmse:0.94450
# [147]	validation_0-rmse:0.94449
# [148]	validation_0-rmse:0.94448
# [149]	validation_0-rmse:0.94447
# [150]	validation_0-rmse:0.94446
# [151]	validation_0-rmse:0.94445
# [152]	validation_0-rmse:0.94445
# [153]	validation_0-rmse:0.94445
# [154]	validation_0-rmse:0.94445
# [155]	validation_0-rmse:0.94444
# [156]	validation_0-rmse:0.94445
# [157]	validation_0-rmse:0.94445
# [158]	validation_0-rmse:0.94444
# [159]	validation_0-rmse:0.94443
# [160]	validation_0-rmse:0.94443
# [161]	validation_0-rmse:0.94443
# [162]	validation_0-rmse:0.94442
# [163]	validation_0-rmse:0.94441
# [164]	validation_0-rmse:0.94440
# [165]	validation_0-rmse:0.94440
# [166]	validation_0-rmse:0.94439
# [167]	validation_0-rmse:0.94440
# [168]	validation_0-rmse:0.94439
# [169]	validation_0-rmse:0.94440
# [170]	validation_0-rmse:0.94439
# [171]	validation_0-rmse:0.94439
# [172]	validation_0-rmse:0.94439
# [173]	validation_0-rmse:0.94440
# [174]	validation_0-rmse:0.94440
# [175]	validation_0-rmse:0.94441
# [176]	validation_0-rmse:0.94441
# [177]	validation_0-rmse:0.94441
# [178]	validation_0-rmse:0.94441
# [179]	validation_0-rmse:0.94440
# [180]	validation_0-rmse:0.94440
# [181]	validation_0-rmse:0.94440
# [182]	validation_0-rmse:0.94441
# [183]	validation_0-rmse:0.94441
# [184]	validation_0-rmse:0.94441
# [185]	validation_0-rmse:0.94440
# [186]	validation_0-rmse:0.94439
# ols method will be used
#              predict
# count  280721.000000
# mean       -0.000154
# std         0.001381
# min        -0.056890
# 25%        -0.000783
# 50%        -0.000079
# 75%         0.000584
# max         0.029578

# %%
ic, icir, rank_ic, rank_icir = q.ic_ana(pred["predict"], y_test, groupby='datetime')
print('ic=', ic, 'icir=', icir, 'rank_ic=', rank_ic, 'rank_icir=', rank_icir)
# 使用pearson相关系数评判拟合优度
r = q.pearson_corr(pred["predict"].values, y_test)
r
# Out:
# ic= 0.0374402474168715 icir= 0.2580987660449074 rank_ic= 0.031637214697116264 rank_icir= 0.2142509929387004
# 0.03350961603908639

# %%
from scutquant import executor, report

# 将预测值处理成回测需要的格式
pred = executor.prepare(pred, df_test, price='mean_price', volume='vol')
pred
# Out:
#                        predict       price     volume
# time       code
# 2019-01-02 000001.SZ  0.000133    9.252048  539386.32
#            000002.SZ -0.001460   24.120738  247010.28
#            000063.SZ  0.000362   19.088275  649682.72
#            000069.SZ -0.000405    5.999183  403924.79
#            000100.SZ  0.000686    2.515065  890514.27
# ...                        ...         ...        ...
# 2022-12-27 688363.SH -0.000956  136.312691   67620.51
#            688396.SH  0.000608   53.127821   22894.05
#            688561.SH -0.001903   65.791178   17585.16
#            688599.SH -0.000226   62.192181  170829.80
#            688981.SH -0.000328   41.078327   61293.26
#
# [280267 rows x 3 columns]

# %%
report.group_return_ana(pred, y_test)
# Out:
# Accuracy of Prediction: 0.5285459936417773

# %%
backtest = {
    "generator": {
        "mode": "generate"
    },
    "strategy": {
        "class": "TopKStrategy",
        "kwargs": {
            "sigma": 1,
            "auto_offset": False,
            "offset_freq": 2, # 应为delta_t + 1, 例如目标值是close_-2 / close_-1 - 1, 则delta_t = 1
            "buy_only": False,  # =True时，只做多不做空(在A股做空有一定的难度)
            "short_volume": 5000,
            "risk_degree": 0.95,  # 将风险度控制在这个数，如果超过了就按比例减持股票直到风险度小于等于它为止
            "unit": None,  # 由于数据已经是以手为单位, 故无需二次处理
            "max_volume": 0.5  # 手数随可用资金而改变，最大不会超过股票当天成交量的x%(例如T+1时下单，下单手数不会超过T时成交量的x%)
        }
    },
    "account": None,  # 使用默认账户, 即初始资金为1亿, 无底仓
    "trade_params": {
        "cost_buy": 0.0015,  # 佣金加上印花税
        "cost_sell": 0.0005,  
        "min_cost": 5,
    }
}
generator, strategy, account, trade_params = backtest["generator"], backtest["strategy"], backtest["account"], backtest["trade_params"]
exe = executor.Executor(generator, strategy, account, trade_params)
exe.execute(data=pred, verbose=0)

# %%
user_account, benchmark = exe.user_account, exe.benchmark
report.report_all(user_account, benchmark, freq=365, time=exe.time)  # 无风险收益率默认为年化3%，可以通过参数rf调节
# Out:
# Annualized Return: 0.1940169345696967
# Annualized Volatility: 0.6854791445163279
# Annualized Return(Benchmark): 0.07899686073853784
# Annualized Volatility(Benchmark): 0.3390023870788162
#
# Cumulative Rate of Return: 0.9775326194812777
# Cumulative Rate of Return(Benchmark): 0.33958556303554865
# Cumulative Excess Rate of Return: 0.637947056445729
#
# Max Drawdown: -0.36789364374663447
# Max Drawdown(Benchmark): -0.5462600364770351
#
# Sharpe Ratio: 2.0266236254657417
# Sortino Ratio: 2.2411252122277014
# Information Ratio: 0.840947707999432
#
# Beta: 1.762210990258477
# Alpha: -0.02201028037896169
# Epsilon: 0.17142817002427035
# Profitable Days(%): 0.9401444788441693
